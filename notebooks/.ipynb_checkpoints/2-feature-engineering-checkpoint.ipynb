# %% [markdown]
# # Libraries

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/fps-dataset.csv')
print(df.shape)
df.head()
# Out:
# (404442, 41)
#                  CpuName  CpuNumberOfCores  CpuNumberOfThreads  CpuBaseClock  \
# 0   b'Intel Core i7-920'               4.0                 8.0         133.0
# 1   b'Intel Core i7-920'               4.0                 8.0         133.0
# 2  b'Intel Core i5-4690'               4.0                 4.0         100.0
# 3  b'Intel Core i5-4690'               4.0                 4.0         100.0
# 4  b'Intel Core i5-4690'               4.0                 4.0         100.0
#
#    CpuCacheL1  CpuCacheL2  CpuCacheL3  CpuFrequency  CpuMultiplier  \
# 0       256.0      1024.0         8.0        2666.0           20.0
# 1       256.0      1024.0         8.0        2666.0           20.0
# 2       256.0      1024.0         6.0        3400.0           34.0
# 3       256.0      1024.0         6.0        3400.0           34.0
# 4       256.0      1024.0         6.0        3400.0           34.0
#
#   CpuMultiplierUnlocked  ...  GpuNumberOfShadingUnits  GpuNumberOfTMUs  \
# 0                  b'0'  ...                   2304.0            144.0
# 1                  b'0'  ...                   2304.0            144.0
# 2                  b'0'  ...                   2560.0            160.0
# 3                  b'0'  ...                   2560.0            160.0
# 4                  b'0'  ...                    896.0             56.0
#
#    GpuTextureRate GpuNumberOfTransistors   GpuVulkan  \
# 0        182300.0                 5700.0  b'1.2.131'
# 1        182300.0                 5700.0  b'1.2.131'
# 2        277300.0                 7200.0  b'1.2.131'
# 3        277300.0                 7200.0  b'1.2.131'
# 4         61600.0                 2080.0  b'1.2.131'
#
#                           GameName  GameResolution  GameSetting  \
# 0  b'counterStrikeGlobalOffensive'          1080.0       b'low'
# 1  b'counterStrikeGlobalOffensive'          1080.0       b'low'
# 2  b'counterStrikeGlobalOffensive'          1080.0       b'low'
# 3  b'counterStrikeGlobalOffensive'          1080.0       b'low'
# 4  b'counterStrikeGlobalOffensive'          1080.0       b'low'
#
#             Dataset    FPS
# 0  b'userbenchmark'   70.0
# 1  b'userbenchmark'  230.0
# 2  b'userbenchmark'  250.0
# 3  b'userbenchmark'  300.0
# 4  b'userbenchmark'  200.0
#
# [5 rows x 41 columns]

# %%
# Showing basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404442 entries, 0 to 404441
# Data columns (total 41 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   CpuName                  404442 non-null  object
#  1   CpuNumberOfCores         404442 non-null  float64
#  2   CpuNumberOfThreads       404442 non-null  float64
#  3   CpuBaseClock             404442 non-null  float64
#  4   CpuCacheL1               404442 non-null  float64
#  5   CpuCacheL2               404442 non-null  float64
#  6   CpuCacheL3               404442 non-null  float64
#  7   CpuFrequency             404442 non-null  float64
#  8   CpuMultiplier            404442 non-null  float64
#  9   CpuMultiplierUnlocked    404442 non-null  object
#  10  CpuProcessSize           404442 non-null  float64
#  11  CpuTDP                   404442 non-null  float64
#  12  CpuTurboClock            404442 non-null  float64
#  13  GpuName                  404442 non-null  object
#  14  GpuArchitecture          404442 non-null  object
#  15  GpuBandwidth             404442 non-null  float64
#  16  GpuBaseClock             404442 non-null  float64
#  17  GpuBoostClock            404442 non-null  float64
#  18  GpuBus nterface          404442 non-null  object
#  19  GpuDieSize               404442 non-null  float64
#  20  GpuDirectX               404442 non-null  object
#  21  GpuFP32Performance       404442 non-null  float64
#  22  GpuMemoryBus             404442 non-null  float64
#  23  GpuMemorySize            404442 non-null  float64
#  24  GpuMemoryType            404442 non-null  object
#  25  GpuOpenCL                404442 non-null  object
#  26  GpuOpenGL                404442 non-null  object
#  27  GpuPixelRate             404442 non-null  float64
#  28  GpuProcessSize           404442 non-null  float64
#  29  GpuNumberOfROPs          404442 non-null  float64
#  30  GpuShaderModel           404442 non-null  object
#  31  GpuNumberOfShadingUnits  404442 non-null  float64
#  32  GpuNumberOfTMUs          404442 non-null  float64
#  33  GpuTextureRate           404442 non-null  float64
#  34  GpuNumberOfTransistors   404442 non-null  float64
#  35  GpuVulkan                404442 non-null  object
#  36  GameName                 404442 non-null  object
#  37  GameResolution           404442 non-null  float64
#  38  GameSetting              404442 non-null  object
#  39  Dataset                  404442 non-null  object
#  40  FPS                      404442 non-null  float64
# dtypes: float64(27), object(14)
# memory usage: 126.5+ MB

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## André Pilco

# %% [markdown]
# ### GPU to CPU ratio
# In order to identify bottlenecks or imbalances, we calculate the ratio of GPU to CPU.

# %%
df['GpuCpuRatio'] = df.apply(lambda row: row['GpuBoostClock'] / row['CpuTurboClock'], axis = 1)

# %% [markdown]
# ### Cache to Core ratio
# Analyzing the ratio of CPU cache size (L1, L2 and L3) to the number of cores

# %%
df['CacheCoreRatio'] = df.apply(lambda row: (row['CpuCacheL1'] + row['CpuCacheL2'] + row['CpuCacheL3']) / row['CpuNumberOfCores'], axis = 1)

# %%
df.head()
# Out:
#                  CpuName  CpuNumberOfCores  CpuNumberOfThreads  CpuBaseClock  \
# 0   b'Intel Core i7-920'               4.0                 8.0         133.0
# 1   b'Intel Core i7-920'               4.0                 8.0         133.0
# 2  b'Intel Core i5-4690'               4.0                 4.0         100.0
# 3  b'Intel Core i5-4690'               4.0                 4.0         100.0
# 4  b'Intel Core i5-4690'               4.0                 4.0         100.0
#
#    CpuCacheL1  CpuCacheL2  CpuCacheL3  CpuFrequency  CpuMultiplier  \
# 0       256.0      1024.0         8.0        2666.0           20.0
# 1       256.0      1024.0         8.0        2666.0           20.0
# 2       256.0      1024.0         6.0        3400.0           34.0
# 3       256.0      1024.0         6.0        3400.0           34.0
# 4       256.0      1024.0         6.0        3400.0           34.0
#
#   CpuMultiplierUnlocked  ...  GpuTextureRate  GpuNumberOfTransistors  \
# 0                  b'0'  ...        182300.0                  5700.0
# 1                  b'0'  ...        182300.0                  5700.0
# 2                  b'0'  ...        277300.0                  7200.0
# 3                  b'0'  ...        277300.0                  7200.0
# 4                  b'0'  ...         61600.0                  2080.0
#
#     GpuVulkan                         GameName GameResolution  GameSetting  \
# 0  b'1.2.131'  b'counterStrikeGlobalOffensive'         1080.0       b'low'
# 1  b'1.2.131'  b'counterStrikeGlobalOffensive'         1080.0       b'low'
# 2  b'1.2.131'  b'counterStrikeGlobalOffensive'         1080.0       b'low'
# 3  b'1.2.131'  b'counterStrikeGlobalOffensive'         1080.0       b'low'
# 4  b'1.2.131'  b'counterStrikeGlobalOffensive'         1080.0       b'low'
#
#             Dataset    FPS GpuCpuRatio  CacheCoreRatio
# 0  b'userbenchmark'   70.0    0.431640           322.0
# 1  b'userbenchmark'  230.0    0.431640           322.0
# 2  b'userbenchmark'  250.0    0.456053           321.5
# 3  b'userbenchmark'  300.0    0.456053           321.5
# 4  b'userbenchmark'  200.0    0.289474           321.5
#
# [5 rows x 43 columns]

# %% [markdown]
# ## John Sovero

# %% [markdown]
# ## Iam Alvarez
